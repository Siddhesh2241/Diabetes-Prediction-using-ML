# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
 import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {
    'Category': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Value': [10, 20, 15, 5, 15, 10],
    'Type': ['Group 1', 'Group 1', 'Group 1', 'Group 2', 'Group 2', 'Group 2']
}

df = pd.DataFrame(data)

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x='Category', y='Value', hue='Type', data=df)
plt.title('Comparison of Two Groups')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# %%
# define the parameter grid
param_grid = { 'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'poly', 'rbf', 'sigmoid'], 'gamma': [1, 0.1, 0.01, 0.001] }

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %%
grid_search = GridSearchCV(modelSVM,param_grid,cv=1,scoring="accuracy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 grid_search = GridSearchCV(modelSVM,param_grid,cv=1,scoring="accuracy")
#
# NameError: name 'modelSVM' is not defined

# %%
grid_search.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 grid_search.fit(x_train,y_train)
#
# NameError: name 'grid_search' is not defined

# %%
print("The Best parameter found: ",grid_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print("The Best parameter found: ",grid_search.best_params_)
#
# NameError: name 'grid_search' is not defined

# %%
print("The Best cross validation accuracy: ",grid_search.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print("The Best cross validation accuracy: ",grid_search.best_score_)
#
# NameError: name 'grid_search' is not defined

# %% [markdown]
# plt.figure(figsize=(8,6))
# n_feature=8
# plt.barh(range(n_feature),modelRF.feature_importances_,align="center")
# diabetes_feature=[x for i ,x in enumerate(data.columns) if i != 8]
# plt.yticks(np.arange(n_feature),diabetes_feature)
# plt.xlabel("Feature importance")
# plt.ylabel("Feature")
# plt.ylim(-1,n_feature)
# plt.show()
